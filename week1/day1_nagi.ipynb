# %%
import os
from dotenv import load_dotenv
from scraper import fetch_website_contents
from IPython.display import Markdown,display
from openai import OpenAI

# %%
load_dotenv(override=True)

api_key=os.getenv('OPENAI_API_KEY')

# %%
if not api_key:
    print("No API key was found - please head over to the troubleshooting notebook in this folder to identify & fix!")
elif not api_key.startswith("sk-proj-"):
    print("An API key was found, but it doesn't start sk-proj-; please check you're using the right key - see troubleshooting notebook")
elif api_key.strip() != api_key:
    print("An API key was found, but it looks like it might have space or tab characters at the start or end - please remove them - see troubleshooting notebook")
else:
    print("API key found and looks good so far!")
# Out:
# API key found and looks good so far!

# %%
message="Hello, GPT! This is my first ever message to you! Hi!"

messages=[{'role':'user','content':message}]
messages
# Out:
# [{'role': 'user',
#   'content': 'Hello, GPT! This is my first ever message to you! Hi!'}]

# %%
openai=OpenAI()
response=openai.chat.completions.create(model="gpt-5-nano",messages=messages)
response.choices[0].message.content
# Out:
# '4'

# %%
ed=fetch_website_contents("https://edwarddonner.com")
print(ed)
# Out:
# Home - Edward Donner
#
# Home
# AI Curriculum
# Connect Four
# Outsmart
# An arena that pits LLMs against each other in a battle of diplomacy and deviousness
# About
# Posts
# Well, hi there.
# I’m Ed. I like writing code and experimenting with LLMs, and hopefully you’re here because you do too. I also enjoy amateur electronic music production (
# very
# amateur) and losing myself in
# Hacker News
# , nodding my head sagely to things I only half understand.
# I’m the co-founder and CTO of
# Nebula.io
# . We’re applying AI to a field where it can make a massive, positive impact: helping people discover their potential and pursue their reason for being. I’m previously the founder and CEO of AI startup untapt,
# acquired in 2021
# .
# If left unchecked, I will happily drone on about LLMs to anyone that will listen. My friends got fed up with my impromptu lectures, and convinced me to make some Udemy courses. To my total joy (and shock) they’ve become best-selling, top-rated courses, with 400,000 enrolled across 190 countries. The
# full curriculum is here
# . If you’re visiting from one of my courses – I’m super grateful!
# Keep in touch
# I’ll only ever contact you occasionally, and
# I’ll always aim to add value with every email.
# Thank you!
# I’ll keep you posted.
# Enter your email…
# Warning
# Stay in touch
# Submitting form
# Δ
# January 4, 2026
# AI Builder with n8n – Create Agents and Voice Agents
# November 11, 2025
# The Unique Energy of an AI Live Event
# September 15, 2025
# AI Engineering MLOps Track – Deploy AI to Production
# May 28, 2025
# Which order to take the AI courses?
# Navigation
# Home
# AI Curriculum
# Connect Four
# Outsmart
# An arena that pits LLMs against each other in a battle of diplomacy and deviousness
# About
# Posts
# Get in touch
# ed [at] edwarddonner [dot] com
# www.edwarddonner.com
# Follow me
# LinkedIn
# Twitter
# Facebook
# Subscribe to newsletter
# Type your email…
# Subscribe

# %%
system_prompt = """
You are an assistant that analyzes the contents of a website,
and provides a short, snarky, humorous summary, ignoring text that might be navigation related.
Respond in markdown. Do not wrap the markdown in a code block - respond just with the markdown.
"""

# %%
user_prompt_prefix = """
Here are the contents of a website.
Provide a short summary of this website.
If it includes news or announcements, then summarize these too.

"""

# %%
messages=[{'role':'system','content':"you are a  helpful assistant"},
{'role':'user','content':"what is 2 +2 ?"}]
response=openai.chat.completions.create(model="gpt-5-nano",messages=messages)
response.choices[0].message.content
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 3
#       1 messages=[{'role':'system','content':"you are a  helpful assistant"},
#       2 {'role':'user','content':"what is 2 +2 ?"}]
# ----> 3 response=openai.chat.completions.create(model="gpt-5-nano",messages=messages)
#       4 response.choices[0].message.content
#
# NameError: name 'openai' is not defined

# %%
def message_for(website):
    return [
        {'role':'system','content':system_prompt},
        {'role':'user','content':user_prompt_prefix + website}
    ]

# %%
message_for(ed)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 message_for(ed)
#
# NameError: name 'ed' is not defined

# %%
def summarize(url):
    website1=fetch_website_contents(url)
    response=openai.chat.completions.create(
        model="gpt-4.1-mini",
        messages=message_for(website1)
    )
    return response.choices[0].message.content

# %%
summarize("https://edwarddonner.com")
# Out:
# '# Edward Donner’s Playground for AI Nerds\n\nWelcome to Ed’s digital lair, where coding, LLM geekery, and amateur electronic beats collide. Ed’s your friendly CTO and serial AI startup founder who’s taken his overenthusiastic monologues about large language models and turned them into wildly successful Udemy courses with half a million students worldwide. \n\nIf you’re here, you’ve probably got a thing for AI, battling LLMs in a digital gladiator arena called *Outsmart* or just want to climb the AI curriculum ladder. He promises occasional emails that might actually be worth your time (please). \n\n## Latest Hits from the AI Newswire\n- **Jan 2026:** Build AI and Voice Agents with n8n (because why not?)\n- **Nov 2025:** Experience the "Unique Energy" of an AI Live Event (buzzword alert!)\n- **Sept 2025:** AI Engineering MLOps Track to put your AI creations into the real world\n- **May 2025:** How to order those AI courses — because chaos is not an option\n\nSo buckle up, subscribe, and prepare to be awash in AI wisdom sprinkled with just enough snark to keep things interesting.'

# %%
def display_website(url):
    summary=summarize(url)
    display(Markdown(summary))

# %%
display_website("https://edwarddonner.com")
# Out:
# # Edward Donner's Playground of AI Shenanigans
#
# Ed is your friendly neighborhood LLM fanatic who wrote a bunch of Udemy courses that somehow hooked 400,000 people worldwide — yes, *people actually pay him to hear him drone on about AI*. When not drowning in Hacker News jargon or making "very amateur" electronic music, he’s busy bossing around AI bots in his game-like arena called Outsmart, where large language models duke it out in diplomatic, backstabbing battles.
#
# Newsflash: Ed’s been busy dropping AI goodies like voice agent builders (Jan 2026), AI live events (Nov 2025), and a full-on AI Engineering MLOps track (Sep 2025). So if you’re hungry for AI mastery or just want to sign up for occasional emails that won’t suck, this is your spot. Plus, he’s CTO at Nebula.io, making AI help us mere mortals find our life’s purpose — no big deal.
#
# In short: Ed’s brain is an AI Swiss Army knife — handy, amusing, and maybe a little geeky.
